# %% [markdown]
# # Aula 5.1 - Apresentação do Caso Sigma
# **Curso:** Programação Python para Análise de Dados Investigativa
# **Caso:** Sigma - dados 100% fictícios.
#
# ## Objetivo
# Conhecer fontes, hipóteses e limites do caso.
#
# > Regra didática: preserve os arquivos originais, documente transformações e trate achados estatísticos como indícios a serem verificados.

# %% [markdown]
# ## Exemplo guiado

# %%
from pathlib import Path

# Encontra a raiz do curso mesmo quando o notebook é executado dentro do workspace
# ou diretamente na pasta do projeto.
pasta_atual = Path.cwd().resolve()
candidatos = (pasta_atual, *pasta_atual.parents)

# Caso 1: notebook executado dentro da raiz do projeto.
# Caso 2: workspace aberto na pasta pai do repositório.
BASE = next((
    pasta for pasta in candidatos
    if (pasta / 'dados' / 'bases').exists()
), None)

if BASE is None:
    BASE = next((
        pasta for pasta in candidatos
        if (pasta / 'Curso_Python_Analise_Dados_Investigativa_Caso_Sigma' / 'dados' / 'bases').exists()
    ), None)
    if BASE is not None:
        BASE = BASE / 'Curso_Python_Analise_Dados_Investigativa_Caso_Sigma'

if BASE is None:
    raise FileNotFoundError('Não foi possível localizar a pasta dados/bases do curso.')

sorted(p.name for p in (BASE / 'dados' / 'bases').iterdir())
# Out:
# ['erbs.csv',
#  'financeiro.csv',
#  'geolocalizacao.csv',
#  'investigados.csv',
#  'ligacoes.csv',
#  'ocorrencias.csv',
#  'pontos_interesse.csv',
#  'registros_app.json',
#  'societario.csv',
#  'transacoes.csv',
#  'veiculos.csv']

# %% [markdown]
# ## Prática em sala
# 1. Execute o exemplo célula a célula.
# 2. Inspecione tipos, dimensões e saídas.
# 3. Altere um parâmetro e observe o efeito.
# 4. Registre o que foi feito e por quê.
#
# ## Exercícios relacionados
# Projeto integrador: planejar pipeline, minerar, cruzar bases, visualizar, documentar limitações e apresentar.

# %% [markdown]
# ## Desafio extra
# Crie uma variação do exemplo usando os arquivos em `../../dados/` e explique quais validações seriam necessárias antes de usar o resultado em uma análise real.

# %%
# Escreva sua solução aqui
