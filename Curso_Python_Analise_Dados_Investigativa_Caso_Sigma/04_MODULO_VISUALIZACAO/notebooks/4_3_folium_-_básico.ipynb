# %% [markdown]
# # Aula 4.3 - Folium - básico
# **Curso:** Programação Python para Análise de Dados Investigativa
# **Caso:** Sigma - dados 100% fictícios.
#
# ## Objetivo
# Plotar pontos de interesse.
#
# > Regra didática: preserve os arquivos originais, documente transformações e trate achados estatísticos como indícios a serem verificados.

# %% [markdown]
# ## Exemplo guiado

# %%
from pathlib import Path

pasta_atual = Path.cwd().resolve()
candidatos = (pasta_atual, *pasta_atual.parents)
BASE = next((pasta for pasta in candidatos if (pasta / 'dados' / 'bases' / 'pontos_interesse.csv').exists()), None)
if BASE is None:
    BASE = next(
        (
            pasta
            for pasta in candidatos
            if (pasta / 'Curso_Python_Analise_Dados_Investigativa_Caso_Sigma' / 'dados' / 'bases' / 'pontos_interesse.csv').exists()
        ),
        None
    )
    if BASE is not None:
        BASE = BASE / 'Curso_Python_Analise_Dados_Investigativa_Caso_Sigma'

if BASE is None:
    raise FileNotFoundError('Não foi possível localizar a pasta de dados do curso.')


pts = pd.read_csv(BASE / 'dados' / 'bases' / 'pontos_interesse.csv')
m = folium.Map(location=[-8.0476, -34.8770], zoom_start=12)
for _, registro in pts.iterrows():
    folium.Marker(
        [registro.latitude, registro.longitude],
        popup=registro['nome'],
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e59b0498c054bcae2055c06c08944d6c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e59b0498c054bcae2055c06c08944d6c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e59b0498c054bcae2055c06c08944d6c = L.map(
#                 &quot;map_e59b0498c054bcae2055c06c08944d6c&quot;,
#                 {
#                     center: [-8.0476, -34.877],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d00dde22375e152458231e3c4dd3e44 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4d00dde22375e152458231e3c4dd3e44.addTo(map_e59b0498c054bcae2055c06c08944d6c);
#
#
#             var marker_e7afb19bdc24d3cd19a4da9c91436d08 = L.marker(
#                 [-8.0398, -34.8711],
#                 {
# }
#             ).addTo(map_e59b0498c054bcae2055c06c08944d6c);
#
#
#         var popup_c687859e327ec2f99063cbd9edbfbe39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a7457687a0dfb07b7bd047302c3c598 = $(`&lt;div id=&quot;html_8a7457687a0dfb07b7bd047302c3c598&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Residência Aline&lt;/div&gt;`)[0];
#                 popup_c687859e327ec2f99063cbd9edbfbe39.setContent(html_8a7457687a0dfb07b7bd047302c3c598);
#
#
#
#         marker_e7afb19bdc24d3cd19a4da9c91436d08.bindPopup(popup_c687859e327ec2f99063cbd9edbfbe39)
#         ;
#
#
#
#
#             var marker_8fe567a6c2dbb506c8531e460c031e9b = L.marker(
#                 [-8.0522, -34.8813],
#                 {
# }
#             ).addTo(map_e59b0498c054bcae2055c06c08944d6c);
#
#
#         var popup_169a102418b3889dd3377ba6a81799d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fe127b3736d770284265811e29064f1 = $(`&lt;div id=&quot;html_4fe127b3736d770284265811e29064f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ERB 4521&lt;/div&gt;`)[0];
#                 popup_169a102418b3889dd3377ba6a81799d3.setContent(html_4fe127b3736d770284265811e29064f1);
#
#
#
#         marker_8fe567a6c2dbb506c8531e460c031e9b.bindPopup(popup_169a102418b3889dd3377ba6a81799d3)
#         ;
#
#
#
#
#             var marker_b816504cd4d7ddff231ff391d4798538 = L.marker(
#                 [-8.0611, -34.8905],
#                 {
# }
#             ).addTo(map_e59b0498c054bcae2055c06c08944d6c);
#
#
#         var popup_d22de8bbaa6f92590535909f5140197b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_398d01318379d0f19b7b26729a7c1783 = $(`&lt;div id=&quot;html_398d01318379d0f19b7b26729a7c1783&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Local ocorrência 01&lt;/div&gt;`)[0];
#                 popup_d22de8bbaa6f92590535909f5140197b.setContent(html_398d01318379d0f19b7b26729a7c1783);
#
#
#
#         marker_b816504cd4d7ddff231ff391d4798538.bindPopup(popup_d22de8bbaa6f92590535909f5140197b)
#         ;
#
#
#
#
#             var marker_88b907e25c809679ee51675e4793da24 = L.marker(
#                 [-8.045, -34.9002],
#                 {
# }
#             ).addTo(map_e59b0498c054bcae2055c06c08944d6c);
#
#
#         var popup_6bd3789051ef2d30dfd054e78c9456d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4103c7f37eb6b31e1bf37c99ea9ba00 = $(`&lt;div id=&quot;html_f4103c7f37eb6b31e1bf37c99ea9ba00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ALFA COMÉRCIO&lt;/div&gt;`)[0];
#                 popup_6bd3789051ef2d30dfd054e78c9456d4.setContent(html_f4103c7f37eb6b31e1bf37c99ea9ba00);
#
#
#
#         marker_88b907e25c809679ee51675e4793da24.bindPopup(popup_6bd3789051ef2d30dfd054e78c9456d4)
#         ;
#
#
#
#
#             var marker_4c6cebbbb3421e6426b25ff3a023e979 = L.marker(
#                 [-8.0842, -34.907],
#                 {
# }
#             ).addTo(map_e59b0498c054bcae2055c06c08944d6c);
#
#
#         var popup_4974767ccb1758fdbc780af52ec19c23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0cdaa21102f9914c1e2853f14c316a0c = $(`&lt;div id=&quot;html_0cdaa21102f9914c1e2853f14c316a0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Depósito GAMA&lt;/div&gt;`)[0];
#                 popup_4974767ccb1758fdbc780af52ec19c23.setContent(html_0cdaa21102f9914c1e2853f14c316a0c);
#
#
#
#         marker_4c6cebbbb3421e6426

# %% [markdown]
# ## Prática em sala
# 1. Execute o exemplo célula a célula.
# 2. Inspecione tipos, dimensões e saídas.
# 3. Altere um parâmetro e observe o efeito.
# 4. Registre o que foi feito e por quê.
#
# ## Exercícios relacionados
# Exercícios 13-16: linha mensal; mapa com tipos; rede de 10 pares e hub; dashboard HTML.

# %% [markdown]
# ## Desafio extra
# Crie uma variação do exemplo usando os arquivos em `../../dados/` e explique quais validações seriam necessárias antes de usar o resultado em uma análise real.

# %%
# Escreva sua solução aqui
