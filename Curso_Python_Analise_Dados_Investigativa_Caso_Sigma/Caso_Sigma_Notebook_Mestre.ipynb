# %% [markdown]
# # Caso Sigma - Notebook Mestre
# Este notebook serve como ponto de partida para o curso inteiro.
# Dados fictícios, criados exclusivamente para treinamento.

# %%
from pathlib import Path
import pandas as pd
BASE = Path.cwd()
dados = BASE/'dados'/'bases'
print(sorted(p.name for p in dados.iterdir()))

# %% [markdown]
# ## Carregamento das bases centrais

# %%
investigados = pd.read_csv(dados/'investigados.csv', dtype={'cpf':str})
transacoes = pd.read_csv(dados/'transacoes.csv', dtype={'cpf':str})
ligacoes = pd.read_csv(dados/'ligacoes.csv')
societario = pd.read_csv(dados/'societario.csv', dtype={'cpf':str})
print(investigados.shape, transacoes.shape, ligacoes.shape, societario.shape)

# %% [markdown]
# ## Perguntas investigativas didáticas
# - Quem movimenta mais valores?
# - Quais favorecidos concentram recursos?
# - Há fracionamento próximo a R$ 10 mil?
# - Quem é hub de comunicação?
# - Existem coincidências de ERB em janela curta?
# - Quais vínculos societários coincidem com atividade financeira?
