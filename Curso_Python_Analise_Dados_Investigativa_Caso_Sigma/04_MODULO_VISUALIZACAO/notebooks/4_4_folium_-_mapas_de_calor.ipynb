# %% [markdown]
# # Aula 4.4 - Folium - mapas de calor
# **Curso:** Programação Python para Análise de Dados Investigativa
# **Caso:** Sigma - dados 100% fictícios.
#
# ## Objetivo
# Visualizar concentração de ocorrências.
#
# > Regra didática: preserve os arquivos originais, documente transformações e trate achados estatísticos como indícios a serem verificados.

# %% [markdown]
# ## Exemplo guiado

# %%
from pathlib import Path

pasta_atual = Path.cwd().resolve()
candidatos = (pasta_atual, *pasta_atual.parents)
BASE = next((pasta for pasta in candidatos if (pasta / 'dados' / 'bases' / 'ocorrencias.csv').exists()), None)
if BASE is None:
    BASE = next(
        (
            pasta
            for pasta in candidatos
            if (pasta / 'Curso_Python_Analise_Dados_Investigativa_Caso_Sigma' / 'dados' / 'bases' / 'ocorrencias.csv').exists()
        ),
        None
    )
    if BASE is not None:
        BASE = BASE / 'Curso_Python_Analise_Dados_Investigativa_Caso_Sigma'

if BASE is None:
    raise FileNotFoundError('Não foi possível localizar a pasta de dados do curso.')


occ = pd.read_csv(BASE / 'dados' / 'bases' / 'ocorrencias.csv')
mh = folium.Map(location=[-8.0476, -34.8770], zoom_start=12)
HeatMap(occ[['latitude', 'longitude']].values.tolist()).add_to(mh)
mh
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90825d2b7abf9d7a2d20df26cce8ec93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90825d2b7abf9d7a2d20df26cce8ec93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90825d2b7abf9d7a2d20df26cce8ec93 = L.map(
#                 &quot;map_90825d2b7abf9d7a2d20df26cce8ec93&quot;,
#                 {
#                     center: [-8.0476, -34.877],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_52a8b6b7b3fbd54cef8e9904d19a6602 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_52a8b6b7b3fbd54cef8e9904d19a6602.addTo(map_90825d2b7abf9d7a2d20df26cce8ec93);
#
#
#             var heat_map_df5fab84af7ec35b37e1d52370c43913 = L.heatLayer(
#                 [[-8.04385, -34.90237], [-8.062667, -34.888815], [-8.086635, -34.886118], [-8.089213, -34.891277], [-8.044286, -34.890761], [-8.08559, -34.893593], [-8.076727, -34.891338], [-8.03945, -34.91057], [-8.045672, -34.892046], [-8.085985, -34.880507], [-8.045452, -34.895914], [-8.083684, -34.88828], [-8.089557, -34.886295], [-8.043429, -34.905304], [-8.047344, -34.896836], [-8.0459, -34.908118], [-8.064144, -34.892142], [-8.059292, -34.887196], [-8.06759, -34.895187], [-8.087826, -34.884449], [-8.084837, -34.886529], [-8.063362, -34.889066], [-8.034281, -34.900069], [-8.048422, -34.911795], [-8.037991, -34.893693], [-8.063577, -34.88905], [-8.083011, -34.891892], [-8.049376, -34.895309], [-8.040513, -34.892208], [-8.048343, -34.89923], [-8.042075, -34.896515], [-8.053272, -34.896857], [-8.055199, -34.902907], [-8.084275, -34.881904], [-8.048386, -34.897066], [-8.080579, -34.895232], [-8.079012, -34.879722], [-8.046496, -34.90183], [-8.041696, -34.896835], [-8.052905, -34.895837], [-8.059609, -34.897412], [-8.067711, -34.883755], [-8.090306, -34.884183], [-8.062909, -34.887076], [-8.056153, -34.894842], [-8.057257, -34.904573], [-8.065016, -34.881861], [-8.086914, -34.894043], [-8.086336, -34.88011], [-8.041723, -34